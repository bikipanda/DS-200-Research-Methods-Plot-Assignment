# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('C:/Users/pandaonymous/Desktop/New/2.csv')
data = data.drop(36,axis=0)
data = data.fillna(data.loc[0])
#Telangana data is not available for 2012-13 and 13-14 due to it coming into existense recently.
#So I copied Andhrapradesh data into it.

# %%
data = pd.read_csv('C:/Users/pandaonymous/Desktop/New/2.csv')

# %%
data
# Out:
#                 State/UT  2012-13  2013-14  2014-15  2015-16  2016-17  \
# 0         Andhra Pradesh    129.5    126.3    127.0    125.2    133.3
# 1      Andaman & Nicobar    360.1    437.6    451.8    473.0    489.5
# 2      Arunachal Pradesh    114.5    123.8    128.5    144.5    162.7
# 3                  Assam     54.1     60.3     61.1     68.0     71.7
# 4                  Bihar     36.4     38.3     39.6     44.6     45.8
# 5             Chandigarh    259.1    335.9    384.1    417.4    367.9
# 6           Chhattisgarh     88.3     94.9    100.1    112.5    113.9
# 7   Dadra & Nagar Haveli    706.4    870.3   1097.9   1198.5   1278.4
# 8            Daman & Diu    531.8    598.0    647.2    745.5    904.2
# 9                  Delhi    247.1    256.1    269.6    298.3    291.4
# 10                   Goa    659.9    446.5    470.8    500.7    534.8
# 11               Gujarat    285.3    282.0    291.9    314.3    314.5
# ...

# %%
Y12_13 = data.iloc[:,1].values
Y13_14 = data.iloc[:,2].values
Y14_15 = data.iloc[:,3].values
Y15_16 = data.iloc[:,4].values
Y16_17 = data.iloc[:,5].values
Y17_18 = data.iloc[:,6].values
Y18_19 = data.iloc[:,7].values
Y = [Y12_13,Y13_14,Y14_15,Y15_16,Y16_17,Y17_18,Y18_19]
X = ['Y12_13','Y13_14','Y14_15','Y15_16','Y16_17','Y17_18','Y18_19']
bar = np.arange(len(X))

# %%
plt.boxplot(Y)
plt.xticks(bar+1,X)
plt.xlabel('Year')
plt.ylabel('Per capita consumption in Kg')
plt.title('Per capita consumption of petroleum Products in Kg')
plt.savefig('C:/Users/pandaonymous/Desktop/Per capita consumption of petroleum Products in Kg 12-18.jpg',dpi = 400)
plt.show()
